# %% [markdown]
# # Practical 3: Differentiation
#
# In this practical, we will learn how to take derivative of functions obtained by adding, multiplying, substractgind, dividing and composing a small set of "elementary functions". Differential caclulus gives a small set of rules for obtaining the derivative of these composite functions in terms of the derivatives of the elementary functions. The three main rules are linearity (which deal with sums and differences of functions), the product rule (which deal with products and divisions) and the chain rule (which deal with composition).
#
# ## Linearity
# v and two numbers $a$ and $b$. We can write a linear combination of these two functions as follows:
#
# $$
# l(x) = a f(x) + b g(x)~.
# $$
#
# the linearity rule says that the derivative of a linear combination is just the linear combination of the derivatives:
#
# $$
# \frac{\text{d} l(x)}{\text{d}x} = a \frac{\text{d} f(x)}{\text{d}x} + b \frac{\text{d} g(x)}{\text{d}x}
# $$
#
# ### Solved exercise 1
# Use the linearity rule to find the derivative of the polynomial:
#
# $$
# p(x) = \sum_{n=0}^N \alpha_n x^n
# $$
#
# #### Solution
# We can start by writing down the polynomial and using the linearity rule to "push" the derivative inside the sum:
#
# $$
# \frac{\text{d} p(x)}{\text{d}x} = \frac{\text{d}}{\text{d}x} \left( \sum_{n=0}^N \alpha_n x^n \right) = \sum_{n=0}^N \alpha_n  \frac{\text{d}x^n}{\text{d}x}
# $$
#
# We can now use the role for the derivative of a power function:
#
# $$
# \frac{\text{d}x^n}{\text{d}x} = n x^{n-1}
# $$
#
# Hence, the derivative is another polynomial:
#
# $$
# \frac{\text{d} p(x)}{\text{d}x} = \sum_{n=1}^N \alpha_n  n x^{n-1}
# $$
#
# Note that the sum now starts from one since:
#
# $$
# \frac{\text{d} x^0}{\text{d}x} = \frac{\text{d} 1}{\text{d}x} = 0
# $$

# %% [markdown]
# ### Exercises 1
# Find the derivative of the following polynomials:
# - $p(x) = 7 + 2 x + 5 x^2$
# - $p(x) = 3 + 4 x^2 + 3 x^8$
# - $p(x) = 1 + 2 x + 3 x^2 + 4 x^3 + 5 x^4$
# - $p(x) = 3 x + x^7$
#
# #### Solutions
# - $2 + 10 x$
# - $8 x + 24 x^7$
# - $2 + 6 x + 12 x^2 + 20 x^3$
# - $3 + 7 x^6$

# %% [markdown]
# *Enter Ex 1.1 here*
#
# $p(x) = 5 x^2 + 2 x + 7$
#
# Define the derivative of $5 x^2 + 2 x + 7$ using Leibniz notation and solve it:
#
# $\frac{dt}{dx} (5 x^2 + 2 x + 7) = (5*2)x^{2-1} + 2 x^{1-1} = 10x^1 + (2\cdot1) = 10x  + 2$

# %% [markdown]
# *Enter Ex 1.2 here*
#
# $p(x) = 3 x^8 + 4 x^2 + 3$
#
# Define the derivative of $3 x^8 + 4 x^2 + 3$ using Leibniz notation and solve it:
#
# $\frac{dt}{dx} (3 x^8 + 4 x^2 + 3) = (3\cdot8) x^{8-1} + (4\cdot2) x^{2-1} = 24x^7 + 8x $

# %% [markdown]
# *Enter Ex 1.3 here*
#
# $p(x) = 1 + 2 x + 3 x^2 + 4 x^3 + 5 x^4$
#
# Define the derivative of $1 + 2 x + 3 x^2 + 4 x^3 + 5 x^4$ using Leibniz notation and solve it:
#
# $ \frac{dt}{dx} (1 + 2 x + 3 x^2 + 4 x^3 + 5 x^4) = 2 x^{1-1} + (2\cdot3) x^{2-1} + (3\cdot 4) x^{3-1} + (4\cdot5) x^{4-1} = (2\cdot1) + 6x + 12x^2 + 20x^3$
#
# $= 2 + 6x + 12x^2 + 20x^3$

# %% [markdown]
# *Enter Ex 1.4 here*
#
# $p(x) = 3 x + x^7$
#
# Define the derivative of $3 x + x^7$ using Leibniz notation and solve it:
#
# $\frac{dt}{dx} (3 x + x^7) = 3x^{1-1} + 7 \cdot x^{7-1} = (3\cdot1) + 7x^6 = 3 + 7x^6$

# %% [markdown]
# ### Python exercises 1
# plot all these functions together with their derivative. (Hint: You can use lambdas. Use the code in Practical 2)

# %%
import matplotlib.pyplot as plt
import numpy as np

x_range = np.linspace(-5,5,100)

# %%
# Python ex 1.1
f = lambda x: 5*x**2 + 2*x + 7
f_prime = lambda x: 10*x + 2

plt.plot(x_range, [f(x) for x in x_range])
plt.plot(x_range, [f_prime(x) for x in x_range])

# %%
# Python ex 1.2
f = lambda x: 3*x**8 + 4*x**2 + 3
f_prime = lambda x: 24*x**7 + 8*x

plt.plot(x_range, [f(x) for x in x_range])
plt.plot(x_range, [f_prime(x) for x in x_range])

# %%
# Python ex 1.3
f = lambda x: 1 + 2*x + 3*x**2 + 4*x**3 + 5*x**4
f_prime = lambda x: 2 + 6*x + 12*x**2 + 20*x**3

plt.plot(x_range, [f(x) for x in x_range])
plt.plot(x_range, [f_prime(x) for x in x_range])

# %%
# Python ex 1.4
f = lambda x: 3*x + x**7
f_prime = lambda x: 3 + 7*x**6

plt.plot(x_range, [f(x) for x in x_range])
plt.plot(x_range, [f_prime(x) for x in x_range])

# %% [markdown]
# ## Product rule
# Consider two functions $f(x)$ and $g(x)$, the derivative of their product is given by the product rule:
#
# $$
# \frac{\text{d} f(x) g(x)}{\text{d}x} = \frac{\text{d} f(x)}{\text{d}x} g(x) + f(x) \frac{\text{d} g(x)}{\text{d}x}
# $$
#
# ### Solved exercise 2
# Use the product rule to derive the formula for the derivative of a power:
#
# $$
# \frac{\text{d}x^n}{\text{d}x} = n x^{n-1}
# $$
#
# #### Solution
# First of all, let's write the power as a product of two terms:
#
# $$
# \frac{\text{d}x^n}{\text{d}x} = \frac{\text{d}x x^{n-1}}{\text{d}x}
# $$
#
# We can now use the product rule:
#
# $$
# \frac{\text{d}x x^{n-1}}{\text{d}x} = \frac{\text{d}x}{\text{d}x} x^{n-1} + x \frac{\text{d}x^{n-1}}{\text{d}x} = x^{n-1} + x \frac{\text{d}x^{n-1}}{\text{d}x}
# $$
#
# We now have an answer in terms of the derivative of another power, let's therefore use the product rule again:
#
# $$
# x^{n-1} + x \frac{\text{d}x^{n-1}}{\text{d}x} = x^{n-1} + x \left( x^{n-2} + x \frac{\text{d}x^{n-2}}{\text{d}x} \right) = x^{n-1} + x^{n-1} + x \frac{\text{d}x^{n-2}}{\text{d}x} = 2 x^{n-1} + x \frac{\text{d}x^{n-2}}{\text{d}x}
# $$
#
# We can now keep applying this formula other $n - 2$ times until we get $\frac{\text{d}x^{n-n}}{\text{d}x} = 0$. The result is
#
# $$
# \frac{\text{d}x^n}{\text{d}x} = x^{n-1} + \dots + x^{n-1} = n x^{n-1}
# $$

# %% [markdown]
# ### Exercises 2
# Find the derivative of the following functions:
# - $f(x) = \sin(x) x^2$
# - $f(x) = \exp(x) \cos(x)$
# - $f(x) = x \exp(x) + x^2 \cos(x)$
# - $f(x) = \tan(x)^2$
# - $f(x) = e^{2x} + \sin(x) x^3$
# - $f(x) = e^{x} \left(2 \cos(x) + 0.5 \sin(x)\right)$
# - $f(x) = \log(x)^2$
#
# Remember that:
# - $\frac{\text{d}\exp(x)}{\text{d}x} = \exp(x)$
# - $\frac{\text{d}\sin(x)}{\text{d}x} = \cos(x)$
# - $\frac{\text{d}\cos(x)}{\text{d}x} = -\sin(x)$
# - $\frac{\text{d}\log(x)}{\text{d}x} = 1/|x|$
# - $\frac{\text{d}\tan(x)}{\text{d}x} = 1/\cos(x)^2$
#
# #### Solutions
# - $\cos(x) x^2 + 2 \sin(x) x$
# - $\exp(x) \left(\cos(x) - \sin(x) \right)$
# - $\exp(x) (1 + x) + 2x \cos(x) - x^2 \sin(x)$
# - $2 \tan(x)/\cos(x)^2$
# - $2 \exp(2x) + \cos(x) x^3 + 3 \sin(x) x^2$
# - $\exp(x) \left(2.5 \cos(x) - 1.5 \sin(x)  \right)$
# - $ 2\frac{1}{|x|}\log(x)$

# %% [markdown]
# **Side note: I believe Luca said that either $\frac{d}{dx}$ (Leibniz notation) or $f'(x)$ was okay during the lecture; with some rules the notation of $f'(x)$ is easier. If Leibniz notation is the accepted notation then I'll use that one. But in this week I used them interchangably.**
#
# ####*Enter Ex 2.1 here*
#
# $f(x) = \sin(x) x^2$
#
# <br>
#
# $g(x) = \sin(x),\;\; g'(x) = \cos(x)$
#
# $h(x) = x^2,\;\;\;\;\;\;\; h'(x) = 2x$
#
# <br>
#
# By the product rule we can see that:
#
# $ g(x) \cdot h'(x) + g'(x)\cdot h(x) = (\sin(x))(2x) + (\cos(x))(x^2) = 2x\sin(x) + x^2\cos(x)$

# %% [markdown]
# ####*Enter Ex 2.2 here*
#
# $f(x) = \exp(x) \cos(x)$
#
# <br>
#
# $g(x) = \exp(x),\;\; g'(x) = \exp(x)$
#
# $h(x) = \cos(x),\;\; h'(x) = -\sin(x)$
#
# <br>
#
# By the product rule we can see that:
#
# $ g(x) \cdot h'(x) + g'(x)\cdot h(x) = (\exp(x))(-\sin(x)) + (\cos(x))(\exp(x)) = -\sin(x)\exp(x) + \exp(x)cos(x) $
#
# $ = \exp(x) (cos(x) - sin(x))$

# %% [markdown]
# ####*Enter Ex 2.3 here*
#
# $f(x) = x \exp(x) + x^2 \cos(x)$
#
# <br>
#
# $g_1(x) = x,\;\; g'_1(x) = 1$
#
# $h_1(x) = \exp(x),\;\; h'_1(x) = \exp(x)$
#
# Therefore:
#
# $ g_1(x) \cdot h'_1(x) + g'_1(x)\cdot h_1(x) = (x)(e^x) + (e^x)(1) = xe^x + e^x = e^x (x + 1) $
#
# <br>
#
# Furthermore since we differentiate with respect to x, the second part of the function will be:
#
# $g_2(x) = x^2,\;\; g'_2(x) = 2x$
#
# $h_2(x) = \cos(x),\;\; h'_2(x) = -\sin(x)$
#
# <br>
#
# By the product rule we can see that the second part of the function is differentiated like this:
#
# $ g_2(x) \cdot h'_2(x) + g'_2(x)\cdot h_2(x) = (x^2)(-\sin(x)) + (2x)(\cos(x)) = -x^2s\sin(x) + 2x\cos(x) $
#
# <br>
#
# Therefore the formula differentiated as a whole is:
#
# $ e^x (x + 1) -x^2\sin(x) + 2x\cos(x) $

# %% [markdown]
# ####*Enter Ex 2.4 here*
#
# $f(x) = \tan(x)^2 = (\tan(x))(\tan(x))$
#
# <br>
#
# $g(x) = \tan(x),\;\;\; g'(x) = \frac{1}{\cos(x)^2}$
#
# $h(x) = \tan(x),\;\; h'(x) = \frac{1}{\cos(x)^2}$
#
# <br>
#
# By the product rule we can see that:
#
# $ g(x) \cdot h'(x) + g'(x)\cdot h(x) = (\tan(x))(\frac{1}{\cos(x)^2}) + (\frac{1}{\cos(x)^2})(\tan(x)) = \frac{\tan(x)}{\cos(x)^2} +  \frac{\tan(x)}{\cos(x)^2} = \frac{2\tan(x)}{\cos(x)^2}$

# %% [markdown]
# ####*Enter Ex 2.5 here*
#
# $f(x) = e^{2x} + \sin(x) x^3$
#
# <br>
#
# $g(x) = \sin(x),\;\; g'(x) = \cos(x)$
#
# $h(x) = x^3,\;\; h'(x) = 3x^2$
#
# Furthermore since we differentiate with respect to x, the first part of the function will be: $t(x) = e^{2x},\; t'(x) = 2e^{2x}$ (ommiting some steps using the chain rule).
#
# <br>
#
# By the product rule we can see that the second part of the function is differentiated like this:
#
# $ g(x) \cdot h'(x) + g'(x)\cdot h(x) = (\sin(x))(3x^2) + (\cos(x))(x^3) = 3x^2 \sin(x) + x^3\cos(x) $
#
# Therefore the formula differentiated as a whole is:
#
# $ 2e^{2x} + 3x^2 \sin(x) + x^3\cos(x) $

# %% [markdown]
# ####*Enter Ex 2.6 here*
#
# $f(x) = e^{x} \left(2 \cos(x) + 0.5 \sin(x)\right)$
#
# <br>
#
# $g_1(x) = e^{x},\;\; g'_1(x) = e^{x}$
#
# $h_1(x) = (2 \cos(x) + 0.5 \sin(x)),\;\; h'_1(x) = ?)$
#
# <br>
#
# We first need to differentiate $h_1$:
#
# $h_1(x) = g_2(x) + h_2(x)$ where $g_2(x) = 2 \cos(x) $ and $ h_2(x) = 0.5 \sin(x)$
#
# $g'_2(x) = -2 \sin(x) $ (since the derivative of 2 is 0, and by the product rule: $0 \cdot \cos(x) = 0$)
#
# $h'_2(x) =0.5\cos(x) $
#
# Therefore:
#
# $h'_1 = 0.5\cos(x) - 2 \sin(x)$
#
# <br>
#
# Now we can differentiate the entire formula (finally):
#
# $ g_1(x) \cdot h'_1(x) + g'_1(x)\cdot h_1(x) = (e^{x})(0.5\cos(x) - 2 \sin(x)) + (e^{x})(2 \cos(x) + 0.5 \sin(x)) = e^{x} (0.5\cos(x) - 2 \sin(x) + 2 \cos(x) + 0.5 \sin(x)) = e^{x} (2.5\cos(x) - 1.5 \sin(x)) $
#
# <br>
#
# Therefore the formula differentiated as a whole is:
#
# $ e^{x} (2.5\cos(x) - 1.5 \sin(x)) $

# %% [markdown]
# ####*Enter Ex 2.7 here*
#
# $f(x) = \log(x)^2 = (\log(x))(\log(x))$
#
# <br>
#
# $g(x) = \log(x),\;\; g'(x) = \frac{1}{|x|}$
#
# $h(x) = \log(x),\;\; h'(x) = \frac{1}{|x|}$
#
#
# By the product rule we can see that::
#
# $ g(x) \cdot h'(x) + g'(x)\cdot h(x) = (\log(x))(\frac{1}{|x|}) + (\frac{1}{|x|})(\log(x)) = \frac{\log(x)}{|x|} + \frac{\log(x)}{|x|} = \frac{2\log(x)}{|x|} $

# %% [markdown]
# ### Python exercises 2
# plot all these functions together with their derivative. (Hint: You can use lambdas. Use the code in Practical 2. )

# %%
# Python ex 2.1
f = lambda x: np.sin(x) * x**2
f_prime = lambda x: (np.cos(x) * x**2) + (2 * x * np.sin(x))

plt.plot(x_range, [f(x) for x in x_range])
plt.plot(x_range, [f_prime(x) for x in x_range])

# %%
# Python ex 2.2
f = lambda x: np.exp(x) * np.cos(x)
f_prime = lambda x: np.exp(x) * (np.cos(x) - np.sin(x))

plt.plot(x_range, [f(x) for x in x_range])
plt.plot(x_range, [f_prime(x) for x in x_range])

# %%
# Python ex 2.3
f = lambda x: x * np.exp(x) + x**2 * np.cos(x) 
f_prime = lambda x: (np.exp(x) * (1 + x)) + (2*x*np.cos(x)) - (x**2*np.sin(x))

plt.plot(x_range, [f(x) for x in x_range])
plt.plot(x_range, [f_prime(x) for x in x_range])

# %%
# Python ex 2.4
f = lambda x: np.tan(x)**2
f_prime = lambda x: (2 * np.tan(x)) / (np.cos(x)**2)

plt.plot(x_range, [f(x) for x in x_range])
plt.plot(x_range, [f_prime(x) for x in x_range])

# %%
# Python ex 2.5
f = lambda x: (np.exp(2*x)) + (np.sin(x)*x**3) 
f_prime = lambda x: (2 * np.exp(2*x)) + (np.cos(x) * x**3) + (3 * np.sin(x) * x**2)

plt.plot(x_range, [f(x) for x in x_range])
plt.plot(x_range, [f_prime(x) for x in x_range])

# %%
# Python ex 2.6
f = lambda x: np.exp(x) * (2 * np.cos(x) + 0.5 * np.sin(x))
f_prime = lambda x: np.exp(x) * (2.5 * np.cos(x) - 1.5 * np.sin(x))

plt.plot(x_range, [f(x) for x in x_range])
plt.plot(x_range, [f_prime(x) for x in x_range])

# %%
# Python ex 2.7
f = lambda x: np.log(x)**2
f_prime = lambda x: 2 * (1/np.absolute(x)) * np.log(x)

plt.plot(x_range, [f(x) for x in x_range])
plt.plot(x_range, [f_prime(x) for x in x_range])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ## Chain rule
# Consider two functions $y(x)$ and $f(y)$. The composite function is a function of $x$ obtained by applying $y(x)$ first and then $f(y)$ on the output:
#
# $$
# f(y(x))
# $$
#
# $$
# \frac{\text{d}f(y(x))}{\text{d}x} = \frac{\text{d}f(y(x))}{\text{d}y(x)} \frac{\text{d}y(x)}{\text{d} x}
# $$
#
# where $\frac{\text{d}f(y(x))}{\text{d}y(x)}$ is the regular derivative $\frac{\text{d}f(y)}{\text{d}y}$ evaluated at the point $y = y(x)$. For example:
#
# $$
# \frac{\text{d}\cos(\exp(x))}{\text{d}\exp(x)} = \sin(\exp(x))
# $$
#
# Therefore:
#
# $$
# \frac{\text{d}\cos(\exp(x))}{\text{d}x} = \frac{\text{d}\cos(\exp(x))}{\text{d}\exp(x)} \frac{\text{d}\exp(x))}{\text{d}x} = \sin(\exp(x)) \exp(x)
# $$
#
# ### Solved exercise 3
# Find the derivative of
#
# $$
# g(x) = 1/\sin(x)
# $$
#
# Hint: (Write this function as the composition of two functions.
#
# #### Solution
# let's write $g(x)$ as
#
# $$
# g(x) = f(y(x))
# $$
#
# where $y(x) = \sin(x)$ and $f(y) = 1/y$. We can now use the chain rule:
#
# $$
# \frac{\text{d}f(y(x))}{\text{d}x} = \frac{\text{d}f(y(x))}{\text{d}y(x)} \frac{\text{d}y(x)}{\text{d} x} = - \frac{1}{y(x)^2} \frac{\text{d}y(x)}{\text{d} x} = - \frac{1}{\sin(x)^2} (- \cos(x)) = \frac{\cos(x)}{\sin(x)^2}
# $$
#
# where we use the rule for the derivative of $1/y$:
#
# $$
# \frac{\text{d}1/y}{\text{d}y} = - \frac{1}{y^2}
# $$

# %% [markdown]
# ### Bonus exercise
#
# Use the chain rule and the product rule to derive the quotient rule:
#
# $$
# \frac{\text{d}f(x)/g(x)}{\text{d}y} = \frac{\frac{\text{d}f(x)}{\text{d}x} g(x) - f(x) \frac{\text{d}g(x)}{\text{d}x} }{g(x)^2}
# $$
#
# Hint: You should use the same technique of the previous solved exercise.

# %% [markdown]
# *(Optional) Enter bonus exercise here*

# %% [markdown]
# ### Exercises 3
#
# Find the derivative of the following functions using the Chain rule:
# - $f(x) = 1/\exp(x)$
# - $f(x) = e^{\cos(x)}$
# - $f(x) = \cos(x)^2$
# - $f(x) = \exp \left( \sin(2x + 4x^5 + 8 x^6)^2 \right)$
# - $f(x) = e^{3\sin(x) + 2 \cos(x) + x^3}$
# - $f(x) = - 0.5 (z - \phi(x))^2$ (where $z$ is a number and $\phi(x)$ is a function with derivative $\phi'(x)$)
# - $f(x) = \cos(\phi(x))$
# - $f(x) = \log(\phi(x))$
#
#
# Solutions:
# - $- 1/\exp(x)$
# - $- \sin(x) e^{\cos(x)}$
# - $- 2 \cos(x) \sin(x)$
# - $ 2 \exp \left( \sin(2x + 4x^5 + 8 x^6)^2 \right) \sin(2x + 4x^5 + 8 x^6) \cos(2x + 4x^5 + 8 x^6) (2 + 20 x^4 + 48 x^5)$
# - $e^{3\sin(x) + 2 \cos(x) + x^3} \left(3 \cos(x) - 2 \sin(x) + 3 x^2 \right)$
# - $ (z - \phi(x)) \phi'(x)$
# - $-\sin(\phi(x)) \phi'(x)$
# - $\frac{\phi'(x)}{|\phi(x)|}$

# %% [markdown]
# ####*Enter Ex 3.1 here*
#
# $f(x) = \frac{1}{e^x} = e^{-x} $
#
# $ f(y(x)) = e^{y}, \;$ and: $\; f'(y(x)) = e^{y}$
#
# $ y(x) = -x, \;$ and: $\; y'(x) = -1 $
#
# Therefore:
#
# $ f'(y(x)) \cdot y'(x) = e^{y} \cdot -1 = -e^{-x} = -\frac{1}{e^x}$

# %% [markdown]
# ####*Enter Ex 3.2 here*
#
# $ f(x) = e^{\cos(x)} $
#
# $ f(y(x)) = e^{y}, \;$ and: $\; f'(y(x)) = e^{y}$
#
# $ y(x) = cos(x), \;$ and: $\; y'(x) = -sin(x) $
#
# Therefore:
#
# $ f'(y(x)) \cdot y'(x) = e^{y} \cdot -sin(x) = -sin(x) e^{cos(x)} $

# %% [markdown]
# ####*Enter Ex 3.3 here*
#
# $ f(x) = \cos(x)^2 $
#
# $ f(y(x)) = y^2, \;$ and: $\; f'(y(x)) = 2y$
#
# $ y(x) = cos(x), \;$ and: $\; y'(x) = -sin(x) $
#
# Therefore:
#
# $ f'(y(x)) \cdot y'(x) = 2y \cdot -sin(x) = -2cos(x)sin(x) $

# %% [markdown]
# ####*Enter Ex 3.4 here*
#
# $f(x) = exp( \sin(2x + 4x^5 + 8 x^6)^2) $
#
# Chain rule:
#
# $g_1(y(x)) = e^y,\; $ and $g'_1(y(x)) = e^y$
#
# $y(x) = \sin(2x + 4x^5 + 8 x^6)^2,\;$
#
# <br>
#
# Chain rule:
#
# $ h_2(y(x)) = \sin(y) \cdot \sin(y), \;$ and: $\; h_2'(y(x)) = 2cos(y)sin(y)$
#
# $ y(x) = 2x + 4x^5 + 8 x^6, \;$ and: $\; y'(x) = 2 + 20x^4 + 48x^5 $
#
# Therefore:
#
# $ h_2'(y(x)) \cdot y'(x) = 2cos(y)sin(y) \cdot (2 + 20x^4 + 48x^5) = 2cos(2x + 4x^5 + 8 x^6)sin(2x + 4x^5 + 8 x^6)(2 + 20x^4 + 48x^5)$
#
# $y'(x) = 2cos(2x + 4x^5 + 8 x^6)sin(2x + 4x^5 + 8 x^6)(2 + 20x^4 + 48x^5)$
#
# And finally:
#
# $2cos(2x + 4x^5 + 8 x^6)sin(2x + 4x^5 + 8 x^6)(2 + 20x^4 + 48x^5) \cdot e^y$
#
# $ = 2e^{\sin(2x + 4x^5 + 8 x^6)^2}cos(2x + 4x^5 + 8 x^6)sin(2x + 4x^5 + 8 x^6)(2 + 20x^4 + 48x^5)$

# %% [markdown]
# ####*Enter Ex 3.5 here*
#
# $f(x) = e^{3\sin(x) + 2 \cos(x) + x^3} $
#
# $ f(y(x)) = e^y, \;$ and: $\; f'(y(x)) = e^y$
#
# $ y(x) = 3\sin(x) + 2 \cos(x) + x^3, \;$ and: $\; y'(x) = 3\cos(x) - 2 \sin(x) + 3x^2 $
#
# Therefore:
#
# $ f'(y(x)) \cdot y'(x) = e^y \cdot 3\cos(x) - 2 \sin(x) + 3x^2 = (3\cos(x) - 2 \sin(x) + 3x^2) e^{3\sin(x) + 2 \cos(x) + x^3}$

# %% [markdown]
# ####*Enter Ex 3.6 here*
#
# $f(x) = - 0.5 (z - \phi(x))^2 $ (where $z$ is a number and $\phi(x)$ is a function with derivative $\phi'(x))  $
#
# $ f(y(x)) = -0.5 (y)^2, \;$ and: $\; f'(y(x)) = -y$
#
# $ y(x) = z - \phi(x), \;$ and: $\; y'(x) = -\phi'(x) $
#
# Therefore:
#
# $ f'(y(x)) \cdot y'(x) = -y \cdot -\phi'(x) = (z - \phi(x))\phi'(x) $

# %% [markdown]
# ####*Enter Ex 3.7 here*
#
# $f(x) = \cos(\phi(x)) $
#
# $ f(y(x)) = \cos(y), \;$ and: $\; f'(y(x)) = -\sin(y)$
#
# $ y(x) = \phi(x), \;$ and: $\; y'(x) = \phi'(x) $
#
# Therefore:
#
# $ f'(y(x)) \cdot y'(x) = -\sin(y) \cdot \phi'(x) = -\sin(\phi(x)) \phi'(x)$

# %% [markdown]
# ####*Enter Ex 3.8 here*
#
# $f(x) = \log(\phi(x)) $
#
# $ f(y(x)) = \log(y), \;$ and: $\; f'(y(x)) = \frac{1}{|y|}$
#
# $ y(x) = \phi(x), \;$ and: $\; y'(x) = \phi'(x) $
#
# Therefore:
#
# $ f'(y(x)) \cdot y'(x) = \frac{1}{|\phi(x)|} \cdot \phi'(x) = \frac{\phi'(x)}{|\phi(x)|}$

# %% [markdown]
# ### Python exercises 3
# plot all these functions together with their derivative. (Hint: You can use lambdas. Use the code in Practical 2). You can use $\phi(x) = e^{-x^2}$.

# %%
# Define the variable z and the function phi and its derivative
phi = lambda x: np.exp(-x**2)
phi_prime = lambda x: -2*x * np.exp(-x**2)
z = 1

# %%
# Python Ex 3.1
f = lambda x: 1/np.exp(x)
f_prime = lambda x: -1/np.exp(x)

plt.plot(x_range, [f(x) for x in x_range])
plt.plot(x_range, [f_prime(x) for x in x_range])

# %%
# Python Ex 3.2
f = lambda x: np.exp(np.cos(x))
f_prime = lambda x: -np.sin(x) * np.exp(np.cos(x))

plt.plot(x_range, [f(x) for x in x_range])
plt.plot(x_range, [f_prime(x) for x in x_range])

# %%
# Python Ex 3.3
f = lambda x: np.cos(x)**2 
f_prime = lambda x: -2 * np.cos(x) * np.sin(x)

plt.plot(x_range, [f(x) for x in x_range])
plt.plot(x_range, [f_prime(x) for x in x_range])

# %%
# Python Ex 3.4
f = lambda x: np.exp(np.sin(2*x + 4*x**5 + 8*x**6)**2)
f_prime = lambda x: 2 * np.exp( np.sin(2*x + 4*x**5 + 8*x**6)**2) * np.sin(2*x + 4*x**5 + 8*x**6) * np.cos(2*x + 4*x**5 + 8*x**6) * (2 + 20*x**4 + 48*x**5)

plt.plot(x_range, [f(x) for x in x_range])
plt.plot(x_range, [f_prime(x) for x in x_range])

# %%
# Python Ex 3.5
f = lambda x: np.exp(3*np.sin(x) + 2*np.cos(x) + x**3)
f_prime = lambda x: np.exp(3 * np.sin(x) + 2 * np.cos(x) + x**3) * (3 * np.cos(x) - 2 * np.sin(x) + 3*x**2)

plt.plot(x_range, [f(x) for x in x_range])
plt.plot(x_range, [f_prime(x) for x in x_range])

# %%
# Python Ex 3.6
f = lambda x: - 0.5 * (z - phi(x))**2
f_prime = lambda x: (z - phi(x)) * phi_prime(x)

plt.plot(x_range, [f(x) for x in x_range])
plt.plot(x_range, [f_prime(x) for x in x_range])

# %%
# Python Ex 3.7
f = lambda x: np.cos(phi(x))
f_prime = lambda x: -np.sin(phi(x)) / phi_prime(x)

plt.plot(x_range, [f(x) for x in x_range])
plt.plot(x_range, [f_prime(x) for x in x_range])

# %%
# Python Ex 3.8
f = lambda x: np.log(phi(x))
f_prime = lambda x: phi_prime(x) / np.absolute(phi(x))

plt.plot(x_range, [f(x) for x in x_range])
plt.plot(x_range, [f_prime(x) for x in x_range])

# %% [markdown]
# ### Solved exercise 4
# Find the derivative of the following function:
#
# $$
# f(x) = \Gamma(x)^{\phi(x)}
# $$
#
# where $\Gamma(x)$ is a function with derivative $\Gamma'(x)$ and $\phi(x)$ is a function with derivative.
# First of all, we can rewruite this function by applying an exponential followed by a logarith and then use the following property of the log:
#
# $$
# \log(x^k) = k \log(x)
# $$
#
# if we do that, we get:
#
# $$
# \Gamma(x)^{\phi(x)} = \exp{\left(\log(\Gamma(x)^{\phi(x)})\right)} = \exp{\left(\phi(x) \log(\Gamma(x))\right)}
# $$
#
# We can now take the derivative using the chain rule:
#
# $$
# \frac{\text{d} \Gamma(x)^{\phi(x)} }{\text{d}y} = \frac{\text{d} \exp{\left(\phi(x) \log(\Gamma(x))\right)} }{\text{d}y} = \exp{\left(\phi(x) \log(\Gamma(x))\right)} \left(\phi'(x) \log{\Gamma(x) + \phi(x) \frac{\Gamma'(x)}{|\Gamma(x)|}} \right)
# $$
#
# ## Numerical approximation of the derivative
#
# So far, we computed the derivative using analytical techniques. We will now learn how to approximate the derivative numerically using python using finite differences. Remember that the derivative is defined as:
#
# $$
# \frac{\text{d}f(x)}{\text{d}x} = \lim_{\text{d}x \rightarrow 0} \frac{f(x + \text{d}x) - f(x)}{\text{d}x}
# $$
#
# Therefore, we can approximate the derivative as
#
# $$
# \frac{\text{d}f(x)}{\text{d}x} \approx \frac{f(x + \text{d}x) - f(x)}{\text{d}x}
# $$
#
# where $\text{d}x$ is a very small number.
#
# We can implement this in Python as follows:

# %%
import numpy as np
import matplotlib.pyplot as plt

dx = 0.1
x_range = np.arange(-np.pi, np.pi, dx)
f = lambda x: np.sin(x)

df_x = [(f(x + dx) - f(x))/dx for x in x_range]

plt.plot(x_range, f(x_range), label="f(x)")
plt.plot(x_range, df_x, label="Approximate df(x)/dx")
plt.legend(loc="best")

# %% [markdown]
# ### Python exercises 4
#
# Use Python to approximately compute the derivitive of
#
# $$f(x) = \cos \left(x^{2(1.5 + \sin(x))} + x^3\right)$$
#
# from $0$ to $\pi$. Compare the result with the derivative computed using the chain rule. Compute the average root squared error between real derivative and approximation for $\text{d}t$ equal to $0.5$, $0.1$, $0.01$ and $0.001$. Do you expect the error to get small as $\text{d}t$ gets smaller?
#
# In general:
# $$ \dfrac{\Delta f(x)}{\Delta x} = \dfrac{f(x+\Delta x) - f(x)}{\Delta x} $$
#
# As $\Delta x$ gets smaller, the more accurate the graph will be and the smaller the error will be. Using the chain we can see that:
#
# $$\cos \left(x^{2(1.5 + \sin(x))} + x^3\right) $$
#
# <br>
#
# $ f(y(x)) = \cos(y),\;\;\;\;\;\;\;\;\;\;\;\;\;\;   f'(y(x)) = -\sin(y) $
#
# $ y(x) = x^{2(1.5 + \sin(x))} + x^3$
#
# We know that (differentiate the first part of y(x)):
#
# $\ln y_1(x) = \ln x^{2(1.5 + \sin(x))}$
#
# $\ln y_1(x) = 2(1.5 + \sin(x)) \ln x$
#
# $\ln y_1(x) = 3 + 2\sin(x)) \ln x $
#
# $ \frac{1}{y_1(x)} \cdot y_1'(x) = 2\cos(x) \ln x + \frac{sin}{x}$ (By the product rule)
#
# $y_1'(x) = y_1(x) [2\cos(x) \ln x + \frac{sin}{x}]$
#
# $y_1'(x) = x^{2(1.5 + \sin(x))} [2\cos(x) \ln x + \frac{2(1.5 + \sin(x))}{x}]$
#
# <br>
#
# $y_2(x) = x^3 $
#
# $y_2'(x) = 3x^2$
#
# Therefore the whole derivative is:
#
# $ y'(x) = x^{2(1.5 + \sin(x))} [2\cos(x) \ln x + \frac{2(1.5 + \sin(x))}{x}] + 3x^2$
#
# By the product rule:
#
# $f'(y(x)) \cdot y'(x) = (-\sin(y)) \cdot (x^{2(1.5 + \sin(x))} [2\cos(x) \ln x + \frac{2(1.5 + \sin(x))}{x}] + 3x^2)$
#
# $ = -\sin(x^{2(1.5 + \sin(x))} + x^3) (x^{2(1.5 + \sin(x))} [2\cos(x) \ln x + \frac{2(1.5 + \sin(x))}{x}] + 3x^2)$

# %%
# Python Ex 4
f = lambda x: np.cos((x**(2 * (1.5 + np.sin(x)))) + (x**3))
f_prime = lambda x: - np.sin(x**(2*(1.5 + np.sin(x))) + x**3) * (x**(2*(1.5 + np.sin(x))) * (2 * np.cos(x) * np.log(x) + ((2*(1.5 + np.sin(x))) / x)) + 3*x**3)


# Define a general function to minimize code redundancy:
def plot_graphs(dx):
  x_range = np.arange(0, np.pi, dx)
  df_x = [(f(x + dx) - f(x)) / dx for x in x_range]
  plt.plot(x_range, f(x_range), label="f(x)")
  plt.plot(x_range, df_x, label="Approximate df(x)/dx")


# Call the function using dx = 0.5
plot_graphs(0.5)

# %%
# Call the function using dx = 0.1
plot_graphs(0.1)

# %%
# Call the function using dx = 0.01
plot_graphs(0.01)

# %%
# Call the function using dx = 0.001
plot_graphs(0.0000001)

# %%
# Plot the function and its actual derivative
x_range = np.arange(0, np.pi, 0.01)
plt.plot(x_range, f(x_range), label="f(x)")
plt.plot(x_range, [f_prime(x) for x in x_range])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in double_scalars
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in double_scalars
#   This is separate from the ipykernel package so we can avoid doing imports until
